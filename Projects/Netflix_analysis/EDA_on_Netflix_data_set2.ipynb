# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

#importing the dataset
df = pd.read_csv('8. Netflix Dataset.csv')
df
# Out:
#      Show_Id Category                                    Title
# 0         s1  TV Show                                       3%  \
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...  \
# ...

# %%
#head() to show the first few rows of the dataset

df.head()
# Out:
#   Show_Id Category  Title           Director
# 0      s1  TV Show     3%                NaN  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration
# 0    August 14, 2020  TV-MA  4 Seasons  \
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
# tail() to show the few bottom rows

df.tail()
# Out:
#      Show_Id Category                                    Title     Director
# 7784   s7783    Movie                                     Zozo  Josef Fares  \
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...  \
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020  \
# ...

# %%
# shape - tells rows, columns

df.shape
# Out:
# (7789, 11)

# %%
# size - shows the total filled values
df.size
# Out:
# 85679

# %%
# columns - lists the columns in the data set
df.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
# to know the data types of the columns we can say
df.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
# All the above info can simpy obtained by one command
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# <p>TASK #1: finding and removing duplicate data fill if there are any</p>

# %%
df.duplicated()  # method to find duplicated records
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Length: 7789, dtype: bool

# %%
df[df.duplicated()]
# Out:
#      Show_Id Category              Title        Director
# 6300    s684    Movie           Backfire     Dave Patten  \
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States  \
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration
# 6300      April 5, 2019  TV-MA   97 min  \
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type
# 6300  Dramas, Independent Movies, Thrillers  \
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
df.shape
# Out:
# (7789, 11)

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (7787, 11)

# %% [markdown]
# <p>TASK #2 presenting null values with heat map

# %%
df.isnull()         #shows the null values across each fields
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date
# 0       False     False  False      True  False    False         False  \
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
df.isnull().sum()       #counts null vaues in each field
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %% [markdown]
# <P>Displaying the null values using matplotlib heat map</p>

# %%
# df.isnull().sum()
x = list(df.isnull().sum().keys())
y = list(df.isnull().sum())

# %% [markdown]
# <p>Visualizing the null values using seaborn heat map</p>

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# <p>TASK #3 for 'House of cards' who is the director of the show and what is the show id</p
# >

# %%
# using isin() method

df[df['Title'].isin(['House of Cards'])]
# Out:
#      Show_Id Category           Title
# 2832   s2833  TV Show  House of Cards  \
#
#                                                Director
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...  \
#
#                                                    Cast        Country
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States  \
#
#           Release_Date Rating   Duration                     Type
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers  \
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
# using str.contains method

df[df['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title
# 2832   s2833  TV Show  House of Cards  \
#
#                                                Director
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...  \
#
#                                                    Cast        Country
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States  \
#
#           Release_Date Rating   Duration                     Type
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers  \
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# <p>What is the year that has highest number of movie releases?<p>
# <p>show each year movie realease in a bar chart?<p>

# %%
new_df = df.dropna()
new_df.isnull().sum()  # new data frame from the original one that has no null values
# Out:
# Show_Id         0
# Category        0
# Title           0
# Director        0
# Cast            0
# Country         0
# Release_Date    0
# Rating          0
# Duration        0
# Type            0
# Description     0
# dtype: int64

# %%
new_df.loc['new_date'] = pd.to_datetime(new_df['Release_Date'], format='mixed')

# %%
new_df.head()
# Out:
#   Show_Id Category  Title           Director
# 1      s2    Movie  07:19  Jorge Michel Grau  \
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
#
#                                                 Cast        Country
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico  \
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#         Release_Date Rating  Duration
# 1  December 23, 2016  TV-MA    93 min  \
# 2  December 20, 2018      R    78 min
# 3  November 16, 2017  PG-13    80 min
# 4    January 1, 2020  PG-13   123 min
# 5       July 1, 2017  TV-MA  1 Season
#
# ...

# %%
#Number of content released on each year
new_df['year_count'] = new_df.new_date.dt.year
new_df
# Out:
# C:\Users\Marcon Abel\AppData\Local\Temp\ipykernel_12100\4231486594.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['year_count'] = new_df.new_date.dt.year
#          Show_Id Category   Title           Director
# 1             s2    Movie   07:19  Jorge Michel Grau  \
# 2             s3    Movie   23:59       Gilbert Chan
# 3             s4    Movie       9        Shane Acker
# 4             s5    Movie      21     Robert Luketic
# 5             s6  TV Show      46        Serdar Akar
# ...          ...      ...     ...                ...
# 7782       s7781    Movie     Zoo       Shlok Sharma
# 7783       s7782    Movie    Zoom       Peter Hewitt
# 7784       s7783    Movie    Zozo        Josef Fares
# ...

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=new_df, x = 'year_count', order=new_df.new_date.dt.year.value_counts().index[0:10])
# Out:
# <Axes: xlabel='year_count', ylabel='count'>

# %% [markdown]
# <p>Using bar plot<p>

# %%
new_df.new_date.dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='new_date'>
